# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
from ROOT import *

# %%
t1=np.array([]);tc1=np.array([]);risc1=np.array([]);pt1=np.array([])
t2=np.array([]);tc2=np.array([]);risc2=np.array([]);pt2=np.array([])
t3=np.array([]);tc3=np.array([]);risc3=np.array([]);pt3=np.array([])
t4=np.array([]);tc4=np.array([]);risc4=np.array([]);pt4=np.array([])
t5=np.array([]);tc5=np.array([]);risc5=np.array([]);pt5=np.array([])


for line in open("file_1_1s.lvm"):
    d=line.split()
    if len(d)!=4:
        continue
    t1   = np.append(t1,  float(d[0])); tc1   = np.append(tc1,  float(d[1]))
    risc1  = np.append(risc1, float(d[2])); pt1  = np.append(pt1, float(d[3]))

for line in open("file_2_1s.txt"):
    d=line.split()
    if len(d)!=4:
        continue
    t2   = np.append(t2,  float(d[0])); tc2   = np.append(tc2,  float(d[1]))
    risc2  = np.append(risc2, float(d[2])); pt2  = np.append(pt2, float(d[3]))

for line in open("file_3_1s.txt"):
    d=line.split()
    if len(d)!=4:
        continue
    t3   = np.append(t3,  float(d[0])); tc3   = np.append(tc3,  float(d[1]))
    risc3  = np.append(risc3, float(d[2])); pt3  = np.append(pt3, float(d[3]))

for line in open("file_4_0.5s.txt"):
    d=line.split()
    if len(d)!=4:
        continue
    t4   = np.append(t4,  float(d[0])); tc4   = np.append(tc4,  float(d[1]))
    risc4  = np.append(risc4, float(d[2])); pt4  = np.append(pt4, float(d[3]))

for line in open("file_5_1.5s.txt"):
    d=line.split()
    if len(d)!=4:
        continue
    t5   = np.append(t5,  float(d[0])); tc5   = np.append(tc5,  float(d[1]))
    risc5  = np.append(risc5, float(d[2])); pt5  = np.append(pt5, float(d[3]))

fig, (ax1,ax2,ax3,ax4,ax5)=plt.subplots(5,sharex=True,figsize=(10,10))
ax1.plot(t1,-tc1/(2000*41e-6))
ax2.plot(t2,-tc2/(2000*41e-6))
ax3.plot(t3,-tc3/(2000*41e-6))
ax4.plot(t4,-tc4/(2000*41e-6))
ax5.plot(t5,-tc5/(2000*41e-6))

plt.show()

plt.plot(t1,-tc1/(2000*41e-6),t2,-tc2/(2000*41e-6),t3,-tc3/(2000*41e-6),t4,-tc4/(2000*41e-6),t5,-tc5/(2000*41e-6))

plt.show()

# %%
fig= plt.figure(figsize=(10,8))

axes= fig.add_axes([0.1,0.1,0.8,0.8])

axes.set_xlim([4,11])
axes.set_ylim([-2.2,-1.7])

plt.plot(1/t1,np.log(np.sqrt(t1)*tc1),
         1/t2,np.log(np.sqrt(t2)*tc2),
         1/t3,np.log(np.sqrt(t3)*tc3),
         1/t4,np.log(np.sqrt(t4)*tc4),
         1/t5,np.log(np.sqrt(t5)*tc5),)
plt.show()
# Out:
# /tmp/ipykernel_1231/4202093505.py:8: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(1/t1,np.log(np.sqrt(t1)*tc1),
# /tmp/ipykernel_1231/4202093505.py:8: RuntimeWarning: divide by zero encountered in log
#   plt.plot(1/t1,np.log(np.sqrt(t1)*tc1),
# /tmp/ipykernel_1231/4202093505.py:9: RuntimeWarning: divide by zero encountered in divide
#   1/t2,np.log(np.sqrt(t2)*tc2),
# /tmp/ipykernel_1231/4202093505.py:9: RuntimeWarning: divide by zero encountered in log
#   1/t2,np.log(np.sqrt(t2)*tc2),
# /tmp/ipykernel_1231/4202093505.py:10: RuntimeWarning: divide by zero encountered in divide
#   1/t3,np.log(np.sqrt(t3)*tc3),
# /tmp/ipykernel_1231/4202093505.py:10: RuntimeWarning: divide by zero encountered in log
#   1/t3,np.log(np.sqrt(t3)*tc3),
# /tmp/ipykernel_1231/4202093505.py:11: RuntimeWarning: divide by zero encountered in divide
#   1/t4,np.log(np.sqrt(t4)*tc4),
# /tmp/ipykernel_1231/4202093505.py:11: RuntimeWarning: divide by zero encountered in log
# ...
